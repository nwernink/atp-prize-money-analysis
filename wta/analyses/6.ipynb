# %% [markdown]
# # Correlation Between Ranking/Tour Level Matches Played and Prize Money Earned

# %% [markdown]
# The correlation between player rankings and prize money earned as well as tour level matches played and prize money earned is calculated by ranking band (1-50, 50-100, etc.) for each year for singles and doubles separately. The correlations illustrate how related the two variables are to each other.

# %%
import pandas as pd
import datetime
import numpy as np

# %%
START_YEAR = 2009
END_YEAR = datetime.datetime.now().year - 1
MAX_SINGLES = 750
MAX_DOUBLES = 250

# %%
data = []
for year in range(START_YEAR, 2010):
    singles = pd.read_csv(f"../data/players/clean/singles/{year}.gz")

    band_prize_money = 0
    band_prize_money_array = []
    band_matches_played = 0
    band_matches_played_array = []
    band_ranking_array = []

    for rank in range(1, MAX_SINGLES + 1):
        player = singles.loc[singles["ranking"] == rank]
        if not player.empty:
            band_prize_money += player["prize_money"].iloc[0]
            band_prize_money_array.append(player["prize_money"].iloc[0])
            band_matches_played += player["wins"].iloc[0] + player["losses"].iloc[0]
            band_matches_played_array.append(player["wins"].iloc[0] + player["losses"].iloc[0])
            band_ranking_array.append(rank)

        if rank % 50 == 0:
            matches_correlation = np.corrcoef(band_prize_money_array, band_matches_played_array)[0, 1] ** 2
            ranking_correlation = np.corrcoef(band_prize_money_array, band_ranking_array)[1, 0] ** 2

            data.append({
                "year": year,
                "type": "singles",
                "ranking_band": f"{rank - 49} - {rank}",
                "prize_money": band_prize_money,
                "matches_played": band_matches_played,
                "matches_correlation": matches_correlation,
                "ranking_correlation": ranking_correlation
            })

            band_prize_money = 0
            band_prize_money_array = []
            band_matches_played = 0
            band_matches_played_array = []
            band_ranking_array = []


    doubles = pd.read_csv(f"../data/players/clean/doubles/{year}.gz")

    band_prize_money = 0
    band_prize_money_array = []
    band_matches_played = 0
    band_matches_played_array = []
    band_ranking_array = []

    for rank in range(1, MAX_DOUBLES + 1):
        player = doubles.loc[doubles["ranking"] == rank]
        if not player.empty:
            band_prize_money += player["prize_money"].iloc[0]
            band_prize_money_array.append(player["prize_money"].iloc[0])
            band_matches_played += player["wins"].iloc[0] + player["losses"].iloc[0]
            band_matches_played_array.append(player["wins"].iloc[0] + player["losses"].iloc[0])
            band_ranking_array.append(rank)

        if rank % 50 == 0:
            matches_correlation = np.corrcoef(band_prize_money_array, band_matches_played_array)[0, 1] ** 2
            ranking_correlation = np.corrcoef(band_prize_money_array, band_ranking_array)[1, 0] ** 2

            data.append({
                "year": year,
                "type": "doubles",
                "ranking_band": f"{rank - 49} - {rank}",
                "prize_money": band_prize_money,
                "matches_played": band_matches_played,
                "matches_correlation": matches_correlation,
                "ranking_correlation": ranking_correlation
            })

            band_prize_money = 0
            band_prize_money_array = []
            band_matches_played = 0
            band_matches_played_array = []
            band_ranking_array = []

pd.DataFrame(data)
# Out:
#     year     type ranking_band  prize_money  matches_played  \
# 0   2009  singles       1 - 50  63850339.76            2885
# 1   2009  singles     51 - 100  11837144.14            2794
# 2   2009  singles    101 - 150   6190289.78            2683
# 3   2009  singles    151 - 200   3035073.92            2310
# 4   2009  singles    201 - 250   1763875.72            2464
# 5   2009  singles    251 - 300   1183794.36            2637
# 6   2009  singles    301 - 350   1134916.54            2486
# 7   2009  singles    351 - 400    694919.60            2410
# 8   2009  singles    401 - 450    726666.54            2224
# 9   2009  singles    451 - 500    510025.66            2049
# 10  2009  singles    501 - 550    464119.90            1957
# 11  2009  singles    551 - 600    462853.26            1753
# 12  2009  singles    601 - 650    311413.10            1715
# 13  2009  singles    651 - 700    276279.46            1511
# 14  2009  singles    701 - 750    220740.42            1277
# 15  2009  doubles       1 - 50  12472836.96            2192
# 16  2009  doubles     51 - 100   3148432.52            1975
# 17  2009  doubles    101 - 150   1073129.50            1827
# 18  2009  doubles    151 - 200    701596.44            1787
# 19  2009  doubles    201 - 250    437636.90            1500
#
#     matches_correlation  ranking_correlation
# 0              0.110422             0.492861
# 1              0.366910             0.494054
# 2              0.323933             0.289784
# 3              0.464412             0.035177
# 4              0.458182             0.082487
# 5              0.161589             0.016660
# 6              0.215816             0.001963
# 7              0.038798             0.014906
# 8              0.137351             0.124055
# 9              0.003566             0.001536
# 10             0.000014             0.021198
# 11             0.188307             0.000902
# 12             0.381064             0.133960
# 13             0.165967             0.038268
# 14             0.292483             0.053559
# 15             0.116574             0.738797
# 16             0.123690             0.403672
# 17             0.225173             0.158654
# 18             0.282765             0.114102
# 19             0.213702             0.052322
