# %% [markdown]
# # Average Prize Money Per Point at Each Round of Every Tournament

# %% [markdown]
# The average prize money per point at each round of each tournament level is calculated by averaging the prize money per point from each player at each round of each tournament by year.

# %%
import pandas as pd
import datetime

# %%
START_YEAR = 2009
END_YEAR = datetime.datetime.now().year - 1
TOURNAMENT_TYPES = ["P", "PM", "P5", "GS", "IS", "CH", "ITF"]

# %%
df = pd.read_csv(f"../data/tournaments/tournaments_expanded.gz")

# %%
singles = df[df["type"] == "singles"]
doubles = df[df["type"] == "doubles"]

# %%
for tournament_type in TOURNAMENT_TYPES:
    tourney = singles[(singles["tournament_type"] == tournament_type)]

    rounds = tourney["round"].unique()
    for r in rounds:
        tourney_round = tourney[tourney["round"] == r] 
        print(tourney_round[["year", "tournament_type", "round", "average_prize_money_per_point"]])
# Out:
#    year tournament_type round  average_prize_money_per_point
# 0  2009               P     S                     159.131198
#    year tournament_type round  average_prize_money_per_point
# 1  2009               P     Q                     142.956503
#    year tournament_type round  average_prize_money_per_point
# 2  2009               P     F                     224.841342
#    year tournament_type round  average_prize_money_per_point
# 3  2009               P   R16                     148.091586
#    year tournament_type round  average_prize_money_per_point
# 4  2009               P   R32                     562.630078
#    year tournament_type round  average_prize_money_per_point
# 5  2009               P   R64                    2200.428571
#     year tournament_type round  average_prize_money_per_point
# 19  2009              PM     F                     663.439412
#     year tournament_type round  average_prize_money_per_point
# 20  2009              PM   R64                      568.53408
#     year tournament_type round  average_prize_money_per_point
# 21  2009              PM   R16                     232.522383
#     year tournament_type round  average_prize_money_per_point
# 22  2009              PM     Q                     270.135909
#     year tournament_type round  average_prize_money_per_point
# 23  2009              PM   R32                      241.53765
#     year tournament_type round  average_prize_money_per_point
# 24  2009              PM     S                     359.534074
#     year tournament_type round  average_prize_money_per_point
# 25  2009              PM  R128                         1410.0
#     year tournament_type round  average_prize_money_per_point
# 13  2009              P5     S                          250.0
#     year tournament_type round  average_prize_money_per_point
# 14  2009              P5   R32                     224.179894
#     year tournament_type round  average_prize_money_per_point
# 15  2009              P5   R16                     172.429597
#     year tournament_type round  average_prize_money_per_point
# 16  2009              P5     F                     388.888889
#     year tournament_type round  average_prize_money_per_point
# 17  2009              P5     Q                     184.097744
#     year tournament_type round  average_prize_money_per_point
# 18  2009              P5   R64                    4537.254902
#    year tournament_type round  average_prize_money_per_point
# 6  2009              GS     F                     650.174412
#    year tournament_type round  average_prize_money_per_point
# 7  2009              GS     Q                        340.821
#    year tournament_type round  average_prize_money_per_point
# 8  2009              GS     S                         370.01
#    year tournament_type round  average_prize_money_per_point
# 9  2009              GS   R32                     273.298678
#     year tournament_type round  average_prize_money_per_point
# 10  2009              GS   R16                     274.500762
#     year tournament_type round  average_prize_money_per_point
# 11  2009              GS   R64                     249.067052
#     year tournament_type round  average_prize_money_per_point
# 12  2009              GS  R128                    2983.977728
#     year tournament_type round  average_prize_money_per_point
# 26  2009              IS   R32                     898.118602
#     year tournament_type round  average_prize_money_per_point
# 27  2009              IS     S                      82.936949
#     year tournament_type round  average_prize_money_per_point
# 28  2009              IS     F                     124.438527
#     year tournament_type round  average_prize_money_per_point
# 29  2009              IS     Q                      81.277196
#     year tournament_type round  average_prize_money_per_point
# 30  2009              IS   R16                      96.400567
#     year tournament_type round  average_prize_money_per_point
# 31  2009              IS   PRE                            0.0
#     year tournament_type round  average_prize_money_per_point
# 32  2009              IS   R64                          700.0
#     year tournament_type round  average_prize_money_per_point
# 33  2009              CH     F                     747.692308
#     year tournament_type round  average_prize_money_per_point
# 34  2009              CH    R1                     460.887949
#     year tournament_type round  average_prize_money_per_point
# 35  2009              CH    SF                     464.285714
#     year tournament_type round  average_prize_money_per_point
# 39  2009             ITF     F                      84.066376
#     year tournament_type round  average_prize_money_per_point
# 40  2009             ITF   R32                      520.38286
#     year tournament_type round  average_prize_money_per_point
# 41  2009             ITF     S                      59.843158
#     year tournament_type round  average_prize_money_per_point
# 42  2009             ITF   R16                      86.762001
#     year tournament_type round  average_prize_money_per_point
# 43  2009             ITF     Q                      63.568227
#     year tournament_type round  average_prize_money_per_point
# 44  2009             ITF     W                          478.0

# %%
for tournament_type in TOURNAMENT_TYPES:
    tourney = doubles[(doubles["tournament_type"] == tournament_type)]

    rounds = tourney["round"].unique()
    for r in rounds:
        tourney_round = tourney[tourney["round"] == r] 
        print(tourney_round[["year", "tournament_type", "round", "average_prize_money_per_point"]])
# Out:
#     year tournament_type round  average_prize_money_per_point
# 69  2009               P   R16                    1375.678082
#     year tournament_type round  average_prize_money_per_point
# 70  2009               P     Q                      22.436673
#     year tournament_type round  average_prize_money_per_point
# 71  2009               P     F                      34.083544
#     year tournament_type round  average_prize_money_per_point
# 72  2009               P     S                      24.569289
#     year tournament_type round  average_prize_money_per_point
# 64  2009              PM   R32                     440.768932
#     year tournament_type round  average_prize_money_per_point
# 65  2009              PM   R16                      44.216708
#     year tournament_type round  average_prize_money_per_point
# 66  2009              PM     F                     110.005714
#     year tournament_type round  average_prize_money_per_point
# 67  2009              PM     Q                      43.593161
#     year tournament_type round  average_prize_money_per_point
# 68  2009              PM     S                         57.595
#     year tournament_type round  average_prize_money_per_point
# 59  2009              P5     Q                      34.296593
#     year tournament_type round  average_prize_money_per_point
# 60  2009              P5     S                      37.609023
#     year tournament_type round  average_prize_money_per_point
# 61  2009              P5     F                      56.451613
#     year tournament_type round  average_prize_money_per_point
# 62  2009              P5   R16                      56.076175
#     year tournament_type round  average_prize_money_per_point
# 63  2009              P5   R32                         1585.0
#     year tournament_type round  average_prize_money_per_point
# 53  2009              GS   R64                     889.306383
#     year tournament_type round  average_prize_money_per_point
# 54  2009              GS   R32                       44.16151
#     year tournament_type round  average_prize_money_per_point
# 55  2009              GS     Q                        48.3825
#     year tournament_type round  average_prize_money_per_point
# 56  2009              GS     S                       55.65344
#     year tournament_type round  average_prize_money_per_point
# 57  2009              GS     F                       87.43345
#     year tournament_type round  average_prize_money_per_point
# 58  2009              GS   R16                      45.995316
#     year tournament_type round  average_prize_money_per_point
# 49  2009              IS     Q                      12.459955
#     year tournament_type round  average_prize_money_per_point
# 50  2009              IS   R16                     438.571429
#     year tournament_type round  average_prize_money_per_point
# 51  2009              IS     S                       12.14059
#     year tournament_type round  average_prize_money_per_point
# 52  2009              IS     F                      17.724821
#     year tournament_type round  average_prize_money_per_point
# 73  2009              CH     F                     110.294118
#     year tournament_type round  average_prize_money_per_point
# 74  2009              CH    SF                      67.934783
#     year tournament_type round  average_prize_money_per_point
# 45  2009             ITF     Q                        9.81185
#     year tournament_type round  average_prize_money_per_point
# 46  2009             ITF   R16                     132.029126
#     year tournament_type round  average_prize_money_per_point
# 47  2009             ITF     S                       9.568938
#     year tournament_type round  average_prize_money_per_point
# 48  2009             ITF     F                      14.579858
